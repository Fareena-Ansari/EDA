# %%
#EXPLORATORY DATA ANALYSIS


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
global_temp = pd.read_csv(r"C:\Users\ACER\Desktop\EDA\GlobalTemperatures.csv")

# %%
global_temp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
import datetime as dt

# %%
max(global_temp.dt)
# Out:
# '2015-12-01'

# %%
global_temp.dtypes
# Out:
# dt                                            object
# LandAverageTemperature                       float64
# LandAverageTemperatureUncertainty            float64
# LandMaxTemperature                           float64
# LandMaxTemperatureUncertainty                float64
# LandMinTemperature                           float64
# LandMinTemperatureUncertainty                float64
# LandAndOceanAverageTemperature               float64
# LandAndOceanAverageTemperatureUncertainty    float64
# dtype: object

# %%
global_temp.describe()
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty  \
# count             3180.000000                        3180.000000
# mean                 8.374731                           0.938468
# std                  4.381310                           1.096440
# min                 -2.080000                           0.034000
# 25%                  4.312000                           0.186750
# 50%                  8.610500                           0.392000
# 75%                 12.548250                           1.419250
# max                 19.021000                           7.880000
#
#        LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# count         1992.000000                    1992.000000         1992.000000
# mean            14.350601                       0.479782            2.743595
# std              4.309579                       0.583203            4.155835
# ...

# %%
plt.figure(figsize=(18,10))
plt.scatter(data = global_temp, x = 'dt',y = 'LandAverageTemperature')
plt.show()

# %%
global_temp.columns
# Out:
# Index(['dt', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty',
#        'LandMaxTemperature', 'LandMaxTemperatureUncertainty',
#        'LandMinTemperature', 'LandMinTemperatureUncertainty',
#        'LandAndOceanAverageTemperature',
#        'LandAndOceanAverageTemperatureUncertainty'],
#       dtype='object')

# %%
len(global_temp.columns)
# Out:
# 9

# %%
global_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   dt                                         3192 non-null   object
#  1   LandAverageTemperature                     3180 non-null   float64
#  2   LandAverageTemperatureUncertainty          3180 non-null   float64
#  3   LandMaxTemperature                         1992 non-null   float64
#  4   LandMaxTemperatureUncertainty              1992 non-null   float64
#  5   LandMinTemperature                         1992 non-null   float64
#  6   LandMinTemperatureUncertainty              1992 non-null   float64
#  7   LandAndOceanAverageTemperature             1992 non-null   float64
#  8   LandAndOceanAverageTemperatureUncertainty  1992 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 224.6+ KB

# %%
df = global_temp
df.describe()
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty  \
# count             3180.000000                        3180.000000
# mean                 8.374731                           0.938468
# std                  4.381310                           1.096440
# min                 -2.080000                           0.034000
# 25%                  4.312000                           0.186750
# 50%                  8.610500                           0.392000
# 75%                 12.548250                           1.419250
# max                 19.021000                           7.880000
#
#        LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# count         1992.000000                    1992.000000         1992.000000
# mean            14.350601                       0.479782            2.743595
# std              4.309579                       0.583203            4.155835
# ...

# %%
df.isnull()
# Out:
#          dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     False                   False                              False
# 1     False                   False                              False
# 2     False                   False                              False
# 3     False                   False                              False
# 4     False                   False                              False
# ...     ...                     ...                                ...
# 3187  False                   False                              False
# 3188  False                   False                              False
# 3189  False                   False                              False
# 3190  False                   False                              False
# 3191  False                   False                              False
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# ...

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# LandMaxTemperature                           1200
# LandMaxTemperatureUncertainty                1200
# LandMinTemperature                           1200
# LandMinTemperatureUncertainty                1200
# LandAndOceanAverageTemperature               1200
# LandAndOceanAverageTemperatureUncertainty    1200
# LandAverageTemperature                         12
# LandAverageTemperatureUncertainty              12
# dt                                              0
# dtype: int64

# %%
missing_percentages = df.isna().sum().sort_values(ascending = False)/len(df)*100

# %%
missing_percentages
# Out:
# LandMaxTemperature                           37.593985
# LandMaxTemperatureUncertainty                37.593985
# LandMinTemperature                           37.593985
# LandMinTemperatureUncertainty                37.593985
# LandAndOceanAverageTemperature               37.593985
# LandAndOceanAverageTemperatureUncertainty    37.593985
# LandAverageTemperature                        0.375940
# LandAverageTemperatureUncertainty             0.375940
# dt                                            0.000000
# dtype: float64

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
missing_percentages[missing_percentages !=0]
# Out:
# LandMaxTemperature                           37.593985
# LandMaxTemperatureUncertainty                37.593985
# LandMinTemperature                           37.593985
# LandMinTemperatureUncertainty                37.593985
# LandAndOceanAverageTemperature               37.593985
# LandAndOceanAverageTemperatureUncertainty    37.593985
# LandAverageTemperature                        0.375940
# LandAverageTemperatureUncertainty             0.375940
# dtype: float64

# %%
missing_percentages[missing_percentages !=0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.LandAndOceanAverageTemperatureUncertainty
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 3187    0.057
# 3188    0.058
# 3189    0.062
# 3190    0.063
# 3191    0.062
# Name: LandAndOceanAverageTemperatureUncertainty, Length: 3192, dtype: float64

# %%
land = df.LandAndOceanAverageTemperatureUncertainty.value_counts()

# %%
land
# Out:
# 0.061    49
# 0.059    47
# 0.060    45
# 0.062    44
# 0.057    41
#          ..
# 0.332     1
# 0.387     1
# 0.389     1
# 0.417     1
# 0.042     1
# Name: LandAndOceanAverageTemperatureUncertainty, Length: 294, dtype: int64

# %%
sns.set_style("darkgrid")

# %%
sns.histplot(land)
# Out:
# <AxesSubplot:xlabel='LandAndOceanAverageTemperatureUncertainty', ylabel='Count'>

# %%
pip install dash --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# %%
global_temp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
global_temp.dt.sort_values(ascending = False)
# Out:
# 3191    2015-12-01
# 3190    2015-11-01
# 3189    2015-10-01
# 3188    2015-09-01
# 3187    2015-08-01
#            ...
# 4       1750-05-01
# 3       1750-04-01
# 2       1750-03-01
# 1       1750-02-01
# 0       1750-01-01
# Name: dt, Length: 3192, dtype: object

# %%
global_temp.dropna()
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1200  1850-01-01                   0.749                              1.105
# 1201  1850-02-01                   3.071                              1.275
# 1202  1850-03-01                   4.954                              0.955
# 1203  1850-04-01                   7.217                              0.665
# 1204  1850-05-01                  10.004                              0.617
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
global_temp.dt.sort_values(ascending = False)
# Out:
# 3191    2015-12-01
# 3190    2015-11-01
# 3189    2015-10-01
# 3188    2015-09-01
# 3187    2015-08-01
#            ...
# 4       1750-05-01
# 3       1750-04-01
# 2       1750-03-01
# 1       1750-02-01
# 0       1750-01-01
# Name: dt, Length: 3192, dtype: object

# %%
global_temp['LandMaxTemperature'].dropna()
t = global_temp['LandMaxTemperature'].dropna().head(5)

# %%
plt.plot(t)

plt.title("Maximum Land Temp")
plt.xlabel("Temp")
plt.ylabel("Year")

plt.show()

# %%
len(df)
# Out:
# 3192

# %%
ndf = pd.read_csv(r"C:\Users\ACER\Desktop\EDA\GlobalLandTemperaturesByCountry.csv")
ndf
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...

# %%
ndf.isnull()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty  Country
# 0       False               False                          False    False
# 1       False                True                           True    False
# 2       False                True                           True    False
# 3       False                True                           True    False
# 4       False                True                           True    False
# ...       ...                 ...                            ...      ...
# 577457  False               False                          False    False
# 577458  False               False                          False    False
# 577459  False               False                          False    False
# 577460  False               False                          False    False
# 577461  False                True                           True    False
#
# [577462 rows x 4 columns]

# %%
clean = ndf.dropna()

# %%
d = clean.tail(50)
d
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 577411  2009-07-01              15.234                          0.414
# 577412  2009-08-01              18.465                          0.489
# 577413  2009-09-01              22.831                          0.329
# 577414  2009-10-01              24.544                          0.429
# 577415  2009-11-01              23.886                          0.421
# 577416  2009-12-01              24.731                          0.430
# 577417  2010-01-01              24.660                          0.459
# 577418  2010-02-01              24.297                          0.565
# 577419  2010-03-01              23.499                          0.249
# 577420  2010-04-01              21.907                          0.293
# 577421  2010-05-01              20.147                          0.534
# 577422  2010-06-01              16.377                          0.476
# ...

# %%
d[['Country', 'AverageTemperature']].groupby(['Country']).mean().sort_values('AverageTemperature')
# Out:
#           AverageTemperature
# Country
# Zimbabwe            21.53394

# %%
plt.figure(figsize=(9,4))
sns.lineplot(x = "dt", y = "AverageTemperature", data = d)
plt.show()
